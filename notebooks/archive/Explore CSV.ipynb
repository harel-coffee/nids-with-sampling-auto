# %%
import pandas as pd
filename ='/home/juma/data/net_intrusion/CIC-IDS-2018/CSVs_r_0.001/SR_10/FFS_(8,16,4)/Wednesday-14-02-2018_TrafficForML_CICFlowMeter.csv'

# %%
df = pd.read_csv(filename)

# %%
df.shape
# Out:
# (139061, 85)

# %%
df1 = df[df.isna().any(axis=1)]

# %%
with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
    print(df1.iloc[0])
# Out:
# Hash                                         547276340564145
# Flow ID              178.161.129.34-172.31.69.25-57203-445-6
# Src IP                                        178.161.129.34
# Src Port                                               57203
# Dst IP                                          172.31.69.25
# Dst Port                                                 445
# Protocol                                                   6
# Timestamp                             14/02/2018 08:31:17 AM
# Flow Duration                                              0
# Tot Fwd Pkts                                               0
# Tot Bwd Pkts                                               1
# TotLen Fwd Pkts                                            0
# TotLen Bwd Pkts                                            0
# Fwd Pkt Len Max                                            0
# Fwd Pkt Len Min                                            0
# Fwd Pkt Len Mean                                           0
# Fwd Pkt Len Std                                            0
# Bwd Pkt Len Max                                            0
# Bwd Pkt Len Min                                            0
# Bwd Pkt Len Mean                                           0
# Bwd Pkt Len Std                                            0
# Flow Byts/s                                               -1
# Flow Pkts/s                                               -1
# Flow IAT Mean                                            NaN
# Flow IAT Std                                             NaN
# Flow IAT Max                                             NaN
# Flow IAT Min                                             NaN
# Fwd IAT Tot                                                0
# Fwd IAT Mean                                               0
# Fwd IAT Std                                                0
# Fwd IAT Max                                                0
# Fwd IAT Min                                                0
# Bwd IAT Tot                                                0
# Bwd IAT Mean                                               0
# Bwd IAT Std                                                0
# Bwd IAT Max                                                0
# Bwd IAT Min                                                0
# Fwd PSH Flags                                              0
# Bwd PSH Flags                                              0
# Fwd URG Flags                                              0
# Bwd URG Flags                                              0
# Fwd Header Len                                             0
# Bwd Header Len                                            32
# Fwd Pkts/s                                                 0
# Bwd Pkts/s                                                 0
# Pkt Len Min                                                0
# Pkt Len Max                                                0
# Pkt Len Mean                                               0
# Pkt Len Std                                                0
# Pkt Len Var                                                0
# FIN Flag Cnt                                               0
# SYN Flag Cnt                                               1
# RST Flag Cnt                                               0
# PSH Flag Cnt                                               0
# ACK Flag Cnt                                               0
# URG Flag Cnt                                               0
# CWE Flag Count                                             0
# ECE Flag Cnt                                               0
# Down/Up Ratio                                              0
# Pkt Size Avg                                               0
# Fwd Seg Size Avg                                           0
# Bwd Seg Size Avg                                           0
# Fwd Byts/b Avg                                             0
# Fwd Pkts/b Avg                                             0
# Fwd Blk Rate Avg                                           0
# Bwd Byts/b Avg                                             0
# Bwd Pkts/b Avg                                             0
# Bwd Blk Rate Avg                                           0
# Subflow Fwd Pkts                                           0
# Subflow Fwd Byts                                           0
# Subflow Bwd Pkts                                           1
# Subflow Bwd Byts                                           0
# Init Fwd Win Byts                                         -1
# Init Bwd Win Byts                                       8192
# Fwd Act Data Pkts                                          0
# Fwd Seg Size Min                                           0
# Active Mean                                                0
# Active Std                                                 0
# Active Max                                                 0
# Active Min                                                 0
# Idle Mean                                                  0
# Idle Std                                                   0
# Idle Max                                                   0
# Idle Min                                                   0
# Label                                               No Label
# Name: 1, dtype: object

# %%
df1.shape
# Out:
# (43744, 85)

# %%
res.shape
# Out:
# (139061, 85)

# %%
df_nan = df[res]

# %%
df_nan.shape
# Out:
# (139061, 85)

# %%
df_nan
# Out:
#         Hash Flow ID Src IP  Src Port Dst IP  Dst Port  Protocol Timestamp  \
# 0        NaN     NaN    NaN       NaN    NaN       NaN       NaN       NaN
# 1        NaN     NaN    NaN       NaN    NaN       NaN       NaN       NaN
# 2        NaN     NaN    NaN       NaN    NaN       NaN       NaN       NaN
# 3        NaN     NaN    NaN       NaN    NaN       NaN       NaN       NaN
# 4        NaN     NaN    NaN       NaN    NaN       NaN       NaN       NaN
# ...      ...     ...    ...       ...    ...       ...       ...       ...
# 139056   NaN     NaN    NaN       NaN    NaN       NaN       NaN       NaN
# 139057   NaN     NaN    NaN       NaN    NaN       NaN       NaN       NaN
# 139058   NaN     NaN    NaN       NaN    NaN       NaN       NaN       NaN
# 139059   NaN     NaN    NaN       NaN    NaN       NaN       NaN       NaN
# 139060   NaN     NaN    NaN       NaN    NaN       NaN       NaN       NaN
#
#         Flow Duration  Tot Fwd Pkts  ...  Fwd Seg Size Min  Active Mean  \
# 0                 NaN           NaN  ...               NaN          NaN
# 1                 NaN           NaN  ...               NaN          NaN
# 2                 NaN           NaN  ...               NaN          NaN
# 3                 NaN           NaN  ...               NaN          NaN
# 4                 NaN           NaN  ...               NaN          NaN
# ...               ...           ...  ...               ...          ...
# 139056            NaN           NaN  ...               NaN          NaN
# 139057            NaN           NaN  ...               NaN          NaN
# 139058            NaN           NaN  ...               NaN          NaN
# 139059            NaN           NaN  ...               NaN          NaN
# 139060            NaN           NaN  ...               NaN          NaN
#
#         Active Std  Active Max  Active Min  Idle Mean  Idle Std  Idle Max  \
# 0              NaN         NaN         NaN        NaN       NaN       NaN
# 1              NaN         NaN         NaN        NaN       NaN       NaN
# 2              NaN         NaN         NaN        NaN       NaN       NaN
# 3              NaN         NaN         NaN        NaN       NaN       NaN
# 4              NaN         NaN         NaN        NaN       NaN       NaN
# ...            ...         ...         ...        ...       ...       ...
# 139056         NaN         NaN         NaN        NaN       NaN       NaN
# 139057         NaN         NaN         NaN        NaN       NaN       NaN
# 139058         NaN         NaN         NaN        NaN       NaN       NaN
# 139059         NaN         NaN         NaN        NaN       NaN       NaN
# 139060         NaN         NaN         NaN        NaN       NaN       NaN
#
#         Idle Min  Label
# 0            NaN    NaN
# 1            NaN    NaN
# 2            NaN    NaN
# 3            NaN    NaN
# 4            NaN    NaN
# ...          ...    ...
# 139056       NaN    NaN
# 139057       NaN    NaN
# 139058       NaN    NaN
# 139059       NaN    NaN
# 139060       NaN    NaN
#
# [139061 rows x 85 columns]

# %%
checkpoint = torch.load(filename)

# %%
checkpoint.keys()
# Out:
# dict_keys(['state_dict', 'optimizer', 'epoch', 'batch', 'batch_size', 'training_complete'])

# %%
checkpoint['state_dict'].keys()
# Out:
# odict_keys(['conv.0.weight', 'conv.0.bias', 'conv.2.weight', 'conv.2.bias', 'classifier.0.weight', 'classifier.0.bias', 'classifier.2.weight', 'classifier.2.bias'])
